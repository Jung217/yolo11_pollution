# %%
# %pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 882 kB 1.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 11.3 MB 10.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 30.3 MB 11.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.3 MB 10.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 78 kB 10.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.7 MB 10.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 7.8 MB 10.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.4 MB 10.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 54.8 MB 11.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 64 kB 7.6 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 294 kB 10.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 62.1 MB 13.2 MB/s eta 0:00:01    |████▎                           | 8.4 MB 10.6 MB/s eta 0:00:06
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.9 🚀 Python-3.9.6 torch-2.4.1 CPU (Apple M2)
# Setup complete ✅ (8 CPUs, 16.0 GB RAM, 63.2/228.3 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import Image

# %%
# %pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="8E3dANFr1FzKYTTaqbo8")
project = rf.workspace("test-ywqvo").project("pollute-g1jae")
version = project.version(7)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train data=/Users/alex/Desktop/vsCode/yolo11_pollution/pollute-7/data.yaml model="yolo11n.pt" epochs=30 batch=10 imgsz=640 device='mps'
# Out:
# /Users/alex/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# New https://pypi.org/project/ultralytics/8.3.15 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.9 🚀 Python-3.9.6 torch-2.4.1 MPS (Apple M2)
# ...
